# %% [markdown]
# ## 1.Data Processing

# %% [markdown]
# ## Importing Data set

# %%
import pandas as pd
import os 
os.getcwd()
# Out:
# 'D:\\python\\dataset working'

# %%
#1 Csv file
data1=pd.read_csv("D:\\Python\\datasets\\super.csv")
data1
# Out:
#           order_id customer_id  order_date       customer_name  \
# 0   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2   CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 12  CA-2017-114412    AA-10480   4/15/2017        Andrew Allen
# 13  CA-2016-161389    IM-15070   12/5/2016        Irene Maddox
# ...

# %% [markdown]
# ## Duplicating Record peropose

# %%
new_dupliacted=data1[data1.duplicated('customer_id')]
new_dupliacted
# Out:
#           order_id customer_id  order_date       customer_name       state  \
# 1   CA-2016-152156    CG-12520   11/8/2016         Claire Gute    Kentucky
# 4   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell     Florida
# 6   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 7   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 8   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 9   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman  California
# 15  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan       Texas
# 19  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  California
# 20  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  California
#
#            category sub_category     sales
# ...

# %%
#2 scv file
data2=pd.read_csv("D:\\Python\\datasets\\products.csv")
data2
# Out:
#     index customer_id                            Product_name Product_price  \
# 0       0    CG-12520     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1       1    CG-12520   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2       2    DV-13045         realme 8i (Space Black, 128 GB)       ₹15,999
# 3       3    SO-20335          realme 8i (Space Black, 64 GB)       ₹13,999
# 4       4    SO-20335  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5       5    BH-11710  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6       6    BH-11710   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7       7    BH-11710    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 8       8    BH-11710            APPLE iPhone SE (Red, 64 GB)       ₹27,999
# 9       9    BH-11710           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 10     10    BH-11710        realme C21Y (Cross Black, 32 GB)        ₹9,499
# ...

# %% [markdown]
# ## Merging Data

# %%
pd.merge(data1,data2,on='customer_id')
# Out:
#           order_id customer_id order_date       customer_name       state  \
# 0   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    Kentucky
# 1   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    Kentucky
# 2   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    Kentucky
# 3   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    Kentucky
# 4   CA-2016-138688    DV-13045  6/12/2016     Darrin Van Huff  California
# ..             ...         ...        ...                 ...         ...
# 70  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli  California
# 71  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli  California
# 72  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli  California
# 73  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli  California
# 74  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli  California
#
#            category sub_category   sales  index  \
# ...

# %% [markdown]
# ## Without using merge

# %%
(data1,data2)
# Out:
# (          order_id customer_id  order_date       customer_name  \
#  0   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
#  1   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
#  2   CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
#  3   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
#  4   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
#  5   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  6   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  7   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  8   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  9   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
#  12  CA-2017-114412    AA-10480   4/15/2017        Andrew Allen
#  13  CA-2016-161389    IM-15070   12/5/2016        Irene Maddox
# ...

# %% [markdown]
# ## Reshaping Data with states Names

# %%
data3['state']=data3['state'].map({'Kentucky':0,'California':1}).astype(float)
data3
# Out:
#           order_id customer_id order_date       customer_name  state  \
# 0   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 1   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 2   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 3   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 4   CA-2016-138688    DV-13045  6/12/2016     Darrin Van Huff    1.0
# ..             ...         ...        ...                 ...    ...
# 70  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 71  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 72  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 73  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 74  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
#
#            category sub_category   sales  index  \
# 0         Furniture    Bookcases  261.96      0
# ...

# %% [markdown]
# ## Grouping Data by Rating

# %%
data4=data3.groupby('category')
data4.get_group('Furniture')
# Out:
#           order_id customer_id  order_date    customer_name  state   category  \
# 0   CA-2016-152156    CG-12520   11/8/2016      Claire Gute    0.0  Furniture
# 1   CA-2016-152156    CG-12520   11/8/2016      Claire Gute    0.0  Furniture
# 2   CA-2016-152156    CG-12520   11/8/2016      Claire Gute    0.0  Furniture
# 3   CA-2016-152156    CG-12520   11/8/2016      Claire Gute    0.0  Furniture
# 5   US-2015-108966    SO-20335  10/11/2015   Sean O'Donnell    NaN  Furniture
# 6   US-2015-108966    SO-20335  10/11/2015   Sean O'Donnell    NaN  Furniture
# 9   CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman    1.0  Furniture
# 10  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman    1.0  Furniture
# 11  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman    1.0  Furniture
# 12  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman    1.0  Furniture
# 13  CA-2014-115812    BH-11710    6/9/2014  Brosina Hoffman    1.0  Furniture
# ...

# %% [markdown]
# ## Means of column having NaN values

# %%
#Finding the mean of the column having NaN
mean_value=data3['state'].mean()
# Replace NaNs in column state with the
# mean of values in the same column
data3['state'].fillna(value=mean_value, inplace=True)
print('Updated Dataframe:')
data3
# Out:
# Updated Dataframe:
#           order_id customer_id order_date       customer_name  state  \
# 0   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 1   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 2   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 3   CA-2016-152156    CG-12520  11/8/2016         Claire Gute    0.0
# 4   CA-2016-138688    DV-13045  6/12/2016     Darrin Van Huff    1.0
# ..             ...         ...        ...                 ...    ...
# 70  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 71  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 72  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 73  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
# 74  CA-2014-143336    ZD-21925  8/27/2014  Zuschuss Donatelli    1.0
#
#            category sub_category   sales  index  \
# 0         Furniture    Bookcases  261.96      0
# ...

# %%
data3.tail(15)
# Out:
#           order_id customer_id  order_date       customer_name     state  \
# 60  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan  0.936508
# 61  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan  0.936508
# 62  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan  0.936508
# 63  US-2015-118983    HP-14815  11/22/2015       Harold Pawlan  0.936508
# 64  CA-2014-105893    PK-19075  11/11/2014           Pete Kriz  0.936508
# 65  CA-2014-167164    AG-10270   5/13/2014     Alejandro Grove  0.936508
# 66  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# 67  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# 68  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# 69  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# 70  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# 71  CA-2014-143336    ZD-21925   8/27/2014  Zuschuss Donatelli  1.000000
# ...

# %% [markdown]
# ## Concatenating  the two data set

# %%
pd.concat([data1,data2])
# Out:
#           order_id customer_id  order_date       customer_name  \
# 0   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2   CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 12  CA-2017-114412    AA-10480   4/15/2017        Andrew Allen
# 13  CA-2016-161389    IM-15070   12/5/2016        Irene Maddox
# ...

# %% [markdown]
# ## Droping Data

# %%
data2.drop(["index"],axis=1)
# Out:
#    customer_id                            Product_name Product_price  \
# 0     CG-12520     REDMI 9i Sport (Coral Green, 64 GB)        ₹8,799
# 1     CG-12520   realme Narzo 50A (Oxygen Blue, 64 GB)       ₹11,499
# 2     DV-13045         realme 8i (Space Black, 128 GB)       ₹15,999
# 3     SO-20335          realme 8i (Space Black, 64 GB)       ₹13,999
# 4     SO-20335  realme Narzo 50A (Oxygen Green, 64 GB)       ₹11,499
# 5     BH-11710  realme Narzo 50A (Oxygen Blue, 128 GB)       ₹12,499
# 6     BH-11710   REDMI 9i Sport (Metallic Blue, 64 GB)        ₹8,799
# 7     BH-11710    REDMI 9i Sport (Carbon Black, 64 GB)        ₹8,799
# 8     BH-11710            APPLE iPhone SE (Red, 64 GB)       ₹27,999
# 9     BH-11710           POCO C31 (Shadow Gray, 64 GB)        ₹8,999
# 10    BH-11710        realme C21Y (Cross Black, 32 GB)        ₹9,499
# 11    BH-11710        realme C21Y (Cross Black, 64 GB)       ₹10,499
# 12    AA-10480         realme C21Y (Cross Blue, 64 GB)       ₹10,499
# ...

# %% [markdown]
# ## dataframe append method

# %%
data1.append(data2,ignore_index=False)
# Out:
#           order_id customer_id  order_date       customer_name  \
# 0   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 1   CA-2016-152156    CG-12520   11/8/2016         Claire Gute
# 2   CA-2016-138688    DV-13045   6/12/2016     Darrin Van Huff
# 3   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 4   US-2015-108966    SO-20335  10/11/2015      Sean O'Donnell
# 5   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 6   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 7   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 8   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 9   CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 10  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 11  CA-2014-115812    BH-11710    6/9/2014     Brosina Hoffman
# 12  CA-2017-114412    AA-10480   4/15/2017        Andrew Allen
# 13  CA-2016-161389    IM-15070   12/5/2016        Irene Maddox
# ...

# %% [markdown]
# ## Dataset Describe

# %%
data1.describe()
data2.describe()
# Out:
#            index  Product_rating
# count  24.000000       24.000000
# mean   11.500000        4.425000
# std     7.071068        0.084699
# min     0.000000        4.300000
# 25%     5.750000        4.400000
# 50%    11.500000        4.400000
# 75%    17.250000        4.500000
# max    23.000000        4.600000
