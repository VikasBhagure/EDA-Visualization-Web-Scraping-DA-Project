# %% [markdown]
# ## Data Processsing

# %%
#importing Library
import pandas as pd
import numpy as np

# %%
#reading amazon daset
data1=pd.read_csv("Amazon_dataset.csv")
data1
# Out:
#      Unnamed: 0                                       Product_Name  \
# 0             0  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 1             1  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 2             2  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 3             3  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 4             4  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ..          ...                                                ...
# 809         809                              Lava A1 (Blue Silver)
# 810         810  Tecno Pop 5 LTE(Deepsea Luster 2G+32G)| 6.52" ...
# 811         811  Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...
# 812         812  Jio Phone Next 32 GB ROM, 2 GB RAM, Blue, Smar...
# 813         813                        Nokia 105 Single SIM (Blue)
#
#      Product_Rating Product_Price
# 0               4.2      2,690.00
# 1               4.2      6,999.00
# 2               4.2        12,990
# ...

# %%
#reading Flipkarts data set
data2=pd.read_csv("Flipkart_dataset.csv")
data2
# Out:
#      Unnamed: 0                                     Product_Name  \
# 0             0              REDMI 9i Sport (Coral Green, 64 GB)
# 1             1            REDMI 9i Sport (Metallic Blue, 64 GB)
# 2             2             REDMI 9i Sport (Carbon Black, 64 GB)
# 3             3            realme Narzo 50A (Oxygen Blue, 64 GB)
# 4             4           realme Narzo 50A (Oxygen Green, 64 GB)
# ..          ...                                              ...
# 235         235                MOTOROLA e40 (Carbon Gray, 64 GB)
# 236         236             Redmi 9A Sport (Carbon Black, 32 GB)
# 237         237                                    Micromax X389
# 238         238  REDMI Note 10 Lite (Interstellar Black, 128 GB)
# 239         239                  OPPO A31 (Mystery Black, 64 GB)
#
#      Product_Rating Product_Price
# 0               4.4         8,799
# 1               4.4         8,799
# 2               4.4         8,799
# 3               4.4        11,499
# ...

# %% [markdown]
# ## concatenating two data set with the help of concat

# %%
data3=pd.concat([data1,data2],keys=['amazon','flipkart'])
data3
# Out:
#               Unnamed: 0                                       Product_Name  \
# amazon   0             0  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
#          1             1  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
#          2             2  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
#          3             3  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
#          4             4  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ...                  ...                                                ...
# flipkart 235         235                  MOTOROLA e40 (Carbon Gray, 64 GB)
#          236         236               Redmi 9A Sport (Carbon Black, 32 GB)
#          237         237                                      Micromax X389
#          238         238    REDMI Note 10 Lite (Interstellar Black, 128 GB)
#          239         239                    OPPO A31 (Mystery Black, 64 GB)
#
#               Product_Rating Product_Price
# ...

# %%
#storing these data set to new one

# %%
#reading this dataset
data4=pd.read_csv('Amazon_Flipkart_dataset.csv')
data4
# Out:
#      E-Company    No                                       Product_Name  \
# 0       amazon     1  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 1       amazon     2  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 2       amazon     3  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 3       amazon     4  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 4       amazon     5  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ...        ...   ...                                                ...
# 1049  flipkart  1050                  MOTOROLA e40 (Carbon Gray, 64 GB)
# 1050  flipkart  1051               Redmi 9A Sport (Carbon Black, 32 GB)
# 1051  flipkart  1052                                      Micromax X389
# 1052  flipkart  1053    REDMI Note 10 Lite (Interstellar Black, 128 GB)
# 1053  flipkart  1054                    OPPO A31 (Mystery Black, 64 GB)
#
#       Product_Rating Product_Price
# 0                4.2      2,690.00
# ...

# %%
data4.head()
# Out:
#   E-Company  No                                       Product_Name  \
# 0    amazon   1  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 1    amazon   2  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 2    amazon   3  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 3    amazon   4  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 4    amazon   5  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
#
#    Product_Rating Product_Price
# 0             4.2      2,690.00
# 1             4.2      6,999.00
# 2             4.2        12,990
# 3             4.2         9,499
# 4             4.2         7,499

# %%
data4.tail()
# Out:
#      E-Company    No                                     Product_Name  \
# 1049  flipkart  1050                MOTOROLA e40 (Carbon Gray, 64 GB)
# 1050  flipkart  1051             Redmi 9A Sport (Carbon Black, 32 GB)
# 1051  flipkart  1052                                    Micromax X389
# 1052  flipkart  1053  REDMI Note 10 Lite (Interstellar Black, 128 GB)
# 1053  flipkart  1054                  OPPO A31 (Mystery Black, 64 GB)
#
#       Product_Rating Product_Price
# 1049             4.2         9,999
# 1050             4.1         7,749
# 1051             3.9           985
# 1052             4.3        15,174
# 1053             4.3        12,988

# %% [markdown]
# ## Data Cleaning

# %%
#finding null values
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   E-Company       1054 non-null   object
#  1   No              1054 non-null   int64
#  2   Product_Name    1054 non-null   object
#  3   Product_Rating  1054 non-null   float64
#  4   Product_Price   1054 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.3+ KB

# %%
#second method-to find null value
data4.isnull().sum()
# Out:
# E-Company         0
# No                0
# Product_Name      0
# Product_Rating    0
# Product_Price     0
# dtype: int64

# %%
#finding duplicated value
data4.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1049    False
# 1050    False
# 1051    False
# 1052    False
# 1053    False
# Length: 1054, dtype: bool

# %%
#counting duplicate value
data4.duplicated().count()
# Out:
# 1054

# %%
#duplication by using product name
data5=data4[data4.duplicated('Product_Name')]
data5
# Out:
#      E-Company    No                                       Product_Name  \
# 23      amazon    24  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 24      amazon    25  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 25      amazon    26  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 26      amazon    27  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 27      amazon    28  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ...        ...   ...                                                ...
# 1034  flipkart  1035                                      Kechaoda K115
# 1035  flipkart  1036                                      Kechaoda K115
# 1038  flipkart  1039                                           Itel Ace
# 1042  flipkart  1043                     Itel Ace Young Without Charger
# 1048  flipkart  1049                                     LAVA Hero 600+
#
#       Product_Rating Product_Price
# 23               4.2      2,690.00
# ...

# %%
dup.duplicated().count()
# Out:
# 845

# %%
data6=data4.sort_values(ascending=False, by=['Product_Rating'])
data6
# Out:
#      E-Company    No                                       Product_Name  \
# 900   flipkart   901                     APPLE iPhone 12 (Black, 64 GB)
# 833   flipkart   834                    realme C21Y (Cross Blue, 32 GB)
# 832   flipkart   833                   realme C21Y (Cross Black, 32 GB)
# 874   flipkart   875                realme C25_Y (Glacier Blue, 128 GB)
# 843   flipkart   844                             OPPO A12 (Blue, 64 GB)
# ...        ...   ...                                                ...
# 957   flipkart   958  IAIR Basic Feature Dual Sim Mobile Phone with ...
# 1005  flipkart  1006  IAIR Basic Feature Dual Sim Mobile Phone with ...
# 893   flipkart   894  IAIR Basic Feature Dual Sim Mobile Phone with ...
# 917   flipkart   918  IAIR Basic Feature Dual Sim Mobile Phone with ...
# 885   flipkart   886  IAIR Basic Feature Dual Sim Mobile Phone with ...
#
#       Product_Rating Product_Price
# 900              4.7        52,999
# ...

# %%
data7=data4.groupby('Product_Rating')
data7.get_group(4.7)
# Out:
#     E-Company   No                    Product_Name  Product_Rating  \
# 900  flipkart  901  APPLE iPhone 12 (Black, 64 GB)             4.7
#
#     Product_Price
# 900        52,999

# %%
data8=data4.groupby('Product_Rating')
data8.get_group(4.6)
# Out:
#     E-Company   No                      Product_Name  Product_Rating  \
# 832  flipkart  833  realme C21Y (Cross Black, 32 GB)             4.6
# 833  flipkart  834   realme C21Y (Cross Blue, 32 GB)             4.6
#
#     Product_Price
# 832         9,499
# 833         9,499

# %%
data9=data4.groupby('Product_Rating')
data9.get_group(4.5)
# Out:
#     E-Company   No                            Product_Name  Product_Rating  \
# 822  flipkart  823    realme Narzo 50i (Mint Green, 32 GB)             4.5
# 823  flipkart  824  realme Narzo 50i (Carbon Black, 32 GB)             4.5
# 827  flipkart  828          realme 8i (Space Black, 64 GB)             4.5
# 828  flipkart  829        realme C21Y (Cross Black, 64 GB)             4.5
# 829  flipkart  830         realme C21Y (Cross Blue, 64 GB)             4.5
# 839  flipkart  840      realme C25Y (Glacier Blue, 128 GB)             4.5
# 840  flipkart  841        realme C25Y (Metal Grey, 128 GB)             4.5
# 841  flipkart  842        OPPO A12 (Flowing Silver, 64 GB)             4.5
# 843  flipkart  844                  OPPO A12 (Blue, 64 GB)             4.5
# 854  flipkart  855            APPLE iPhone SE (Red, 64 GB)             4.5
# 856  flipkart  857        realme C25_Y (Metal Grey, 64 GB)             4.5
# ...

# %%
data10=data4.groupby('Product_Rating')
data10.get_group(4.4)
# Out:
#      E-Company    No                                     Product_Name  \
# 814   flipkart   815              REDMI 9i Sport (Coral Green, 64 GB)
# 815   flipkart   816            REDMI 9i Sport (Metallic Blue, 64 GB)
# 816   flipkart   817             REDMI 9i Sport (Carbon Black, 64 GB)
# 817   flipkart   818            realme Narzo 50A (Oxygen Blue, 64 GB)
# 818   flipkart   819           realme Narzo 50A (Oxygen Green, 64 GB)
# 819   flipkart   820          realme Narzo 50A (Oxygen Green, 128 GB)
# 820   flipkart   821           realme Narzo 50A (Oxygen Blue, 128 GB)
# 821   flipkart   822                    POCO C31 (Shadow Gray, 64 GB)
# 824   flipkart   825               realme C11 2021 (Cool Blue, 32 GB)
# 825   flipkart   826               realme C11 2021 (Cool Grey, 32 GB)
# 830   flipkart   831                    POCO C31 (Shadow Gray, 32 GB)
# 831   flipkart   832                 realme 8i (Space Purple, 128 GB)
# ...

# %%
data11=data4.groupby('Product_Rating')
data11.get_group(4.3)
# Out:
#      E-Company    No                                       Product_Name  \
# 834   flipkart   835             realme Narzo 50i (Carbon Black, 64 GB)
# 835   flipkart   836                 realme C11 2021 (Cool Blue, 64 GB)
# 836   flipkart   837                 realme C11 2021 (Cool Grey, 64 GB)
# 838   flipkart   839                         REDMI 9i (Sea Blue, 64 GB)
# 844   flipkart   845          Infinix Smart HD 2021 (Topaz Blue, 32 GB)
# 846   flipkart   847                    MOTOROLA g31 (Baby Blue, 64 GB)
# 849   flipkart   850            SAMSUNG Galaxy F22 (Denim Black, 64 GB)
# 852   flipkart   853                   REDMI 9i (Midnight Black, 64 GB)
# 861   flipkart   862                 Infinix Hot 10S (95° Black, 64 GB)
# 867   flipkart   868                 Infinix Hot 10S (95° Black, 64 GB)
# 868   flipkart   869            Infinix Hot 10S (Heart Of Ocean, 64 GB)
# 875   flipkart   876             SAMSUNG Galaxy F22 (Denim Blue, 64 GB)
# ...

# %%
data12=data4.groupby('Product_Rating')
data12.get_group(4.2)
# Out:
#      E-Company    No                                       Product_Name  \
# 0       amazon     1  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 1       amazon     2  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 2       amazon     3  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 3       amazon     4  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 4       amazon     5  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ...        ...   ...                                                ...
# 1020  flipkart  1021                      SAMSUNG Guru Music 2 SM-B315E
# 1032  flipkart  1033                                            LAVA A9
# 1041  flipkart  1042             REDMI 10 Prime (Phantom Black, 128 GB)
# 1043  flipkart  1044                  vivo Y72 5G (Prism Magic, 128 GB)
# 1049  flipkart  1050                  MOTOROLA e40 (Carbon Gray, 64 GB)
#
#       Product_Rating Product_Price
# 0                4.2      2,690.00
# ...

# %%
data12.head(10)
# Out:
#      E-Company    No                                       Product_Name  \
# 0       amazon     1  OPPO A31 (Mystery Black, 6GB RAM, 128GB Storag...
# 1       amazon     2  Redmi 9 Activ (Coral Green, 4GB RAM, 64GB Stor...
# 2       amazon     3  Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...
# 3       amazon     4  Redmi 9A (Nature Green, 3GB Ram, 32GB Storage)...
# 4       amazon     5  OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage...
# ...        ...   ...                                                ...
# 1016  flipkart  1017                     Itel Ace Young Without Charger
# 1025  flipkart  1026                                   BlackZone HAMMER
# 1030  flipkart  1031                                   BlackZone HAMMER
# 1042  flipkart  1043                     Itel Ace Young Without Charger
# 1051  flipkart  1052                                      Micromax X389
#
#       Product_Rating Product_Price
# 0                4.2      2,690.00
# ...
